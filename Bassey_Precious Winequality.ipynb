# %%
Name= "Bassey Precious"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
winequality_dataset=pd.read_csv("winequality.csv")

# %%
winequality_dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data=winequality_dataset

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
plt.rcParams['figure.figsize']
# Out:
# [6.0, 4.0]

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.isnull().any().any()
# Out:
# False

# %%
data.rename(columns={'fixed acidity': 'fixed_acidity',
                     'citric acid':'citric_acid',
                     'volatile acidity':'volatile_acidity',
                     'residual sugar':'residual_sugar',
                     'free sulfur dioxide':'free_sulfur_dioxide',
                     'total sulfur dioxide':'total_sulfur_dioxide'},
            inplace=True)

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
data.quality.value_counts().sort_index()
# Out:
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
plt.figure(figsize=(10,15))

for pl,col in enumerate(list(data.columns.values)):
    plt.subplot(4,3,pl+1)
    sns.set()
    sns.boxplot(col,data=data)
    plt.tight_layout()
# Out:
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
"From the plots, we see that most of the data are right skewed"
# Out:
# 'From the plots, we see that most of the data are right skewed'

# %%
sns.catplot(x='quality', data=data, kind='count');
plt.title('Distribution of the Quality');

# %%
"The quality of wine that appears most in the dataset is 5"
# Out:
# 'The quality of wine that appears most in the dataset is 5'

# %%
data.corr()['quality'].sort_values()
# Out:
# volatile_acidity       -0.390558
# total_sulfur_dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free_sulfur_dioxide    -0.050656
# residual_sugar          0.013732
# fixed_acidity           0.124052
# citric_acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
data_Cor = data.drop(['fixed_acidity', 'volatile_acidity', 'density', 'residual_sugar', 'chlorides','total_sulfur_dioxide'], axis=1)

# %%
sns.pairplot(data_Cor,hue = 'quality');

# %%
plt.figure(figsize=(14,8))
ax = sns.heatmap(data_Cor.corr(), annot = True, cmap='RdPu')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.1, top - 0.1);

# %%
data['pH'].describe()
# Out:
# count    1599.000000
# mean        3.311113
# std         0.154386
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
data['sulphates'].describe()
# Out:
# count    1599.000000
# mean        0.658149
# std         0.169507
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
data['free_sulfur_dioxide'].describe()
# Out:
# count    1599.000000
# mean       15.874922
# std        10.460157
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free_sulfur_dioxide, dtype: float64

# %%
data['alcohol'].describe()
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
data.iloc[:,:11].head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
plt.figure(figsize=(10,15))

for pl,col in enumerate(list(data.iloc[:,:11].columns.values)):
    plt.subplot(4,3,pl+1)
    sns.violinplot(y= data[col],x='quality',data=data, scale='count')
    plt.title(f'quality/{col}')
    plt.tight_layout()

# %%
for col in (data.iloc[:,:11].columns.values):
 
    sns.lmplot(x='quality',y=col,data=data, fit_reg=False)
  
    plt.title(f'quality/{col}');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.lmplot(x='quality',y=col,data=data)
  
    plt.title(f'quality/{col}');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    print('   ')

# %%
condition = [(data['quality']>6),(data['quality']<=4)]#Setting the condition for good and bad ratings

rating = ['good','bad']

# %%
data['rating'] = np.select(condition,rating,default='average')
data.rating.value_counts()
# Out:
# average    1319
# good        217
# bad          63
# Name: rating, dtype: int64

# %%
data.head(25)
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 22            7.9             0.430         0.21             1.6      0.106
# 23            8.5             0.490         0.11             2.3      0.084
# 24            6.9             0.400         0.14             2.4      0.085
#
#     free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
# 20                 29.0                  60.0   0.9968  3.39       0.53
# 21                 23.0                  71.0   0.9982  3.52       0.65
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 23                  9.0                  67.0   0.9968  3.17       0.53
# 24                 21.0                  40.0   0.9968  3.43       0.63
#
#     alcohol  quality   rating
# 0       9.4        5  average
# 1       9.8        5  average
# 2       9.8        5  average
# 3       9.8        6  average
# 4       9.4        5  average
# 5       9.4        5  average
# 6       9.4        5  average
# 7      10.0        7     good
# 8       9.5        7     good
# 9      10.5        5  average
# 10      9.2        5  average
# 11     10.5        5  average
# 12      9.9        5  average
# 13      9.1        5  average
# 14      9.2        5  average
# 15      9.2        5  average
# 16     10.5        7     good
# 17      9.3        5  average
# 18      9.0        4      bad
# 19      9.2        6  average
# 20      9.4        6  average
# 21      9.7        5  average
# 22      9.5        5  average
# 23      9.4        5  average
# 24      9.7        6  average

# %%
for col in data.iloc[:,:11].columns.values:
 
    
    sns.set()
    sns.violinplot(y= col ,x='rating',data=data, scale='count')
    plt.title(f'rating/{col}');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    sns.set()
    sns.swarmplot(x='rating',y=col,data=data)
    plt.title(f'rating/{col}');
    plt.ylabel(col);
    plt.show();
    plt.tight_layout();
    plt.close() 
    
    print('   ')
# Out:
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 83.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 47.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 86.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 56.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 73.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 37.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 72.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ME\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
data[[('rating'),('quality')]].head(25)
# Out:
#      rating  quality
# 0   average        5
# 1   average        5
# 2   average        5
# 3   average        6
# 4   average        5
# 5   average        5
# 6   average        5
# 7      good        7
# 8      good        7
# 9   average        5
# 10  average        5
# 11  average        5
# 12  average        5
# 13  average        5
# 14  average        5
# 15  average        5
# 16     good        7
# 17  average        5
# 18      bad        4
# 19  average        6
# 20  average        6
# 21  average        5
# 22  average        5
# 23  average        5
# 24  average        6

# %%
data.groupby('rating')['quality'].value_counts()
# Out:
# rating   quality
# average  5          681
#          6          638
# bad      4           53
#          3           10
# good     7          199
#          8           18
# Name: quality, dtype: int64

# %%
bins = (2, 4, 9)
group_names = ['bad', 'good']
data['quality'] = pd.cut(data['quality'], bins = bins, labels = group_names)

# %%
data.head(25)
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 22            7.9             0.430         0.21             1.6      0.106
# 23            8.5             0.490         0.11             2.3      0.084
# 24            6.9             0.400         0.14             2.4      0.085
#
#     free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
# 20                 29.0                  60.0   0.9968  3.39       0.53
# 21                 23.0                  71.0   0.9982  3.52       0.65
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 23                  9.0                  67.0   0.9968  3.17       0.53
# 24                 21.0                  40.0   0.9968  3.43       0.63
#
#     alcohol quality   rating
# 0       9.4    good  average
# 1       9.8    good  average
# 2       9.8    good  average
# 3       9.8    good  average
# 4       9.4    good  average
# 5       9.4    good  average
# 6       9.4    good  average
# 7      10.0    good     good
# 8       9.5    good     good
# 9      10.5    good  average
# 10      9.2    good  average
# 11     10.5    good  average
# 12      9.9    good  average
# 13      9.1    good  average
# 14      9.2    good  average
# 15      9.2    good  average
# 16     10.5    good     good
# 17      9.3    good  average
# 18      9.0     bad      bad
# 19      9.2    good  average
# 20      9.4    good  average
# 21      9.7    good  average
# 22      9.5    good  average
# 23      9.4    good  average
# 24      9.7    good  average

# %%
data[[('rating'),('quality')]].head(25)
# Out:
#      rating quality
# 0   average    good
# 1   average    good
# 2   average    good
# 3   average    good
# 4   average    good
# 5   average    good
# 6   average    good
# 7      good    good
# 8      good    good
# 9   average    good
# 10  average    good
# 11  average    good
# 12  average    good
# 13  average    good
# 14  average    good
# 15  average    good
# 16     good    good
# 17  average    good
# 18      bad     bad
# 19  average    good
# 20  average    good
# 21  average    good
# 22  average    good
# 23  average    good
# 24  average    good

# %%
dfL = np.array(data['quality'])

dfL = pd.DataFrame(dfL)

data['quality'] = dfL.apply(lambda x: x.map({'good':1,'bad':0}))

# %%
data.head(30)
# Out:
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 22            7.9             0.430         0.21             1.6      0.106
# 23            8.5             0.490         0.11             2.3      0.084
# 24            6.9             0.400         0.14             2.4      0.085
# 25            6.3             0.390         0.16             1.4      0.080
# 26            7.6             0.410         0.24             1.8      0.080
# 27            7.9             0.430         0.21             1.6      0.106
# 28            7.1             0.710         0.00             1.9      0.080
# 29            7.8             0.645         0.00             2.0      0.082
#
#     free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
# 20                 29.0                  60.0   0.9968  3.39       0.53
# 21                 23.0                  71.0   0.9982  3.52       0.65
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 23                  9.0                  67.0   0.9968  3.17       0.53
# 24                 21.0                  40.0   0.9968  3.43       0.63
# 25                 11.0                  23.0   0.9955  3.34       0.56
# 26                  4.0                  11.0   0.9962  3.28       0.59
# 27                 10.0                  37.0   0.9966  3.17       0.91
# 28                 14.0                  35.0   0.9972  3.47       0.55
# 29                  8.0                  16.0   0.9964  3.38       0.59
#
#     alcohol  quality   rating
# 0       9.4        1  average
# 1       9.8        1  average
# 2       9.8        1  average
# 3       9.8        1  average
# 4       9.4        1  average
# 5       9.4        1  average
# 6       9.4        1  average
# 7      10.0        1     good
# 8       9.5        1     good
# 9      10.5        1  average
# 10      9.2        1  average
# 11     10.5        1  average
# 12      9.9        1  average
# 13      9.1        1  average
# 14      9.2        1  average
# 15      9.2        1  average
# 16     10.5        1     good
# 17      9.3        1  average
# 18      9.0        0      bad
# 19      9.2        1  average
# 20      9.4        1  average
# 21      9.7        1  average
# 22      9.5        1  average
# 23      9.4        1  average
# 24      9.7        1  average
# 25      9.3        1  average
# 26      9.5        1  average
# 27      9.5        1  average
# 28      9.4        1  average
# 29      9.8        1  average

# %%
data[[('rating'),('quality')]].head(25)
# Out:
#      rating  quality
# 0   average        1
# 1   average        1
# 2   average        1
# 3   average        1
# 4   average        1
# 5   average        1
# 6   average        1
# 7      good        1
# 8      good        1
# 9   average        1
# 10  average        1
# 11  average        1
# 12  average        1
# 13  average        1
# 14  average        1
# 15  average        1
# 16     good        1
# 17  average        1
# 18      bad        0
# 19  average        1
# 20  average        1
# 21  average        1
# 22  average        1
# 23  average        1
# 24  average        1

# %%
X, y = data.iloc[: , :-1], data.iloc[: , -1]

# %%
X =  data[['alcohol','density','sulphates','pH','free_sulfur_dioxide','citric_acid']]
Y =  data['quality']

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     0.960600
# std       0.154386     0.169507     1.065668     0.194605
# min       2.740000     0.330000     8.400000     0.000000
# 25%       3.210000     0.550000     9.500000     1.000000
# 50%       3.310000     0.620000    10.200000     1.000000
# 75%       3.400000     0.730000    11.100000     1.000000
# max       4.010000     2.000000    14.900000     1.000000

# %%
#Setting the values of X and Y

X =  data[['alcohol','density','sulphates','pH','free_sulfur_dioxide','citric_acid']]
y =  data['quality']

# %%
X
# Out:
#       alcohol  density  sulphates    pH  free_sulfur_dioxide  citric_acid
# 0         9.4  0.99780       0.56  3.51                 11.0         0.00
# 1         9.8  0.99680       0.68  3.20                 25.0         0.00
# 2         9.8  0.99700       0.65  3.26                 15.0         0.04
# 3         9.8  0.99800       0.58  3.16                 17.0         0.56
# 4         9.4  0.99780       0.56  3.51                 11.0         0.00
# ...       ...      ...        ...   ...                  ...          ...
# 1594     10.5  0.99490       0.58  3.45                 32.0         0.08
# 1595     11.2  0.99512       0.76  3.52                 39.0         0.10
# 1596     11.0  0.99574       0.75  3.42                 29.0         0.13
# 1597     10.2  0.99547       0.71  3.57                 32.0         0.12
# 1598     11.0  0.99549       0.66  3.39                 18.0         0.47
#
# [1599 rows x 6 columns]

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1594    1
# 1595    1
# 1596    1
# 1597    1
# 1598    1
# Name: quality, Length: 1599, dtype: int64

# %%
train_x= X[:70]
test_x= X[:30]
train_y= Y[:70]
test_y= Y[:30]

# %%
import sklearn.model_selection as model_selection
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.7,test_size=0.3, random_state=101)
print ("X_train: ", X_train)
print ("y_train: ", y_train)
print("X_test: ", X_test)
print ("y_test: ", y_test)
# Out:
# X_train:        alcohol  density  sulphates    pH  free_sulfur_dioxide  citric_acid
# 361       9.9  0.99820       0.91  3.37                 21.0         0.31
# 121      10.9  0.99620       0.60  3.21                 14.0         0.04
# 12        9.9  0.99430       0.52  3.58                 16.0         0.00
# 420      11.8  0.99720       0.73  3.28                 35.0         0.33
# 870      11.8  0.99371       0.57  3.41                 31.0         0.01
# ...       ...      ...        ...   ...                  ...          ...
# 75       10.5  0.99860       0.66  3.54                  9.0         0.64
# 599       9.3  1.00000       0.70  3.00                 11.0         0.45
# 1361     10.1  0.99724       0.54  3.36                 13.0         0.14
# 1547     12.1  0.99306       0.51  3.55                 12.0         0.10
# 863       9.7  0.99746       0.53  3.51                 17.0         0.06
#
# [1119 rows x 6 columns]
# y_train:  361     1
# 121     1
# 12      1
# 420     1
# 870     1
#        ..
# 75      1
# 599     1
# 1361    1
# 1547    1
# 863     1
# Name: quality, Length: 1119, dtype: int64
# X_test:        alcohol  density  sulphates    pH  free_sulfur_dioxide  citric_acid
# 678      10.0  0.99830       0.53  3.48                 45.0         0.10
# 1500      9.6  0.99508       0.53  3.26                  8.0         0.04
# 1457      9.0  0.99706       0.58  3.41                 27.0         0.33
# 1079     12.3  0.99316       0.51  3.01                 37.5         0.68
# 909      11.5  0.99331       0.52  3.29                  7.0         0.39
# ...       ...      ...        ...   ...                  ...          ...
# 37        9.7  0.99680       0.73  3.23                 13.0         0.28
# 986      11.4  0.99470       0.55  3.19                  3.0         0.39
# 628       9.3  0.99760       0.60  3.27                  7.0         0.26
# 123       9.5  0.99760       0.53  3.44                 11.0         0.00
# 1343     10.5  0.99538       0.54  3.36                 13.0         0.02
#
# [480 rows x 6 columns]
# y_test:  678     1
# 1500    1
# 1457    1
# 1079    1
# 909     1
#        ..
# 37      1
# 986     1
# 628     1
# 123     1
# 1343    1
# Name: quality, Length: 480, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
X_tr,X_t,y_tr,y_t = train_test_split(X,y)

# %%
X_tr.shape, X_t.shape
# Out:
# ((1199, 6), (400, 6))

# %%
y_tr.shape, y_t.shape
# Out:
# ((1199,), (400,))

# %%
 from sklearn.preprocessing import StandardScaler
stds= StandardScaler()

X_tr= stds.fit_transform(X_tr)
X_t = stds.fit_transform(X_t)

# %%
def generateClassificationReport_Tr(y_true,y_pred):
    '''Train data accuracy tester'''
    print(classification_report(y_true,y_pred));
    print(confusion_matrix(y_true,y_pred));
    print('\n\nTrain Accuracy is: ',
          round(100*accuracy_score(y_true,y_pred),3),'%\n');
    
def generateClassificationReport_T(y_true,y_pred):
    '''Test data accuracy tester'''
    print(classification_report(y_true,y_pred));
    print(confusion_matrix(y_true,y_pred));
    print('\n\nTest Accuracy is: ',
          round(100*accuracy_score(y_true,y_pred),3),'%\n');

# %%
from sklearn.linear_model import LogisticRegression
logr = LogisticRegression(max_iter=1000);
logr.fit(X_tr,y_tr);

# %%
from sklearn.metrics import classification_report
ytr_pred = logr.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
# C:\Users\ME\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        48
#            1       0.96      1.00      0.98      1151
#
#     accuracy                           0.96      1199
#    macro avg       0.48      0.50      0.49      1199
# weighted avg       0.92      0.96      0.94      1199
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-aa046c2f7c71> in <module>
#       1 from sklearn.metrics import classification_report
#       2 ytr_pred = logr.predict(X_tr)
# ----> 3 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       2     '''Train data accuracy tester'''
#       3     print(classification_report(y_true,y_pred));
# ----> 4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
#       6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
yt_pred = logr.predict(X_t)
generateClassificationReport_T(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.96      1.00      0.98       385
#
#     accuracy                           0.96       400
#    macro avg       0.48      0.50      0.49       400
# weighted avg       0.93      0.96      0.94       400
#
# [[  0  15]
#  [  0 385]]
# C:\Users\ME\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-9a985a572a53> in <module>
#       2 from sklearn.metrics import confusion_matrix
#       3 yt_pred = logr.predict(X_t)
# ----> 4 generateClassificationReport_T(y_t,yt_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_T(y_true, y_pred)
#      11     print(confusion_matrix(y_true,y_pred));
#      12     print('\n\nTest Accuracy is: ',
# ---> 13           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_tr,y_tr);

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
ytr_pred = rfc.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00      1151
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199
#
# [[  48    0]
#  [   0 1151]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-b35d80daa244> in <module>
#       3 from sklearn.metrics import confusion_matrix
#       4 ytr_pred = rfc.predict(X_tr)
# ----> 5 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
# ----> 6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#       7
#       8 def generateClassificationReport_T(y_true,y_pred):
#
# NameError: name 'accuracy_score' is not defined

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
gnd = GaussianNB()
gnd.fit(X_tr,y_tr);

# %%
from sklearn.metrics import classification_report
ytr_pred = gnd.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.10      0.02      0.03        48
#            1       0.96      0.99      0.98      1151
#
#     accuracy                           0.95      1199
#    macro avg       0.53      0.51      0.51      1199
# weighted avg       0.93      0.95      0.94      1199
#
# [[   1   47]
#  [   9 1142]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-d29289ebe950> in <module>
#       1 from sklearn.metrics import classification_report
#       2 ytr_pred = gnd.predict(X_tr)
# ----> 3 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
# ----> 6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#       7
#       8 def generateClassificationReport_T(y_true,y_pred):
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.metrics import classification_report
yt_pred = gnd.predict(X_t)
generateClassificationReport_T(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.96      1.00      0.98       385
#
#     accuracy                           0.96       400
#    macro avg       0.48      0.50      0.49       400
# weighted avg       0.93      0.96      0.94       400
#
# [[  0  15]
#  [  1 384]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-b25098316df9> in <module>
#       1 from sklearn.metrics import classification_report
#       2 yt_pred = gnd.predict(X_t)
# ----> 3 generateClassificationReport_T(y_t,yt_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_T(y_true, y_pred)
#      11     print(confusion_matrix(y_true,y_pred));
#      12     print('\n\nTest Accuracy is: ',
# ---> 13           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'accuracy_score' is not defined

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_tr,y_tr);

# %%
from sklearn.metrics import classification_report
from sklearn.svm import SVC
ytr_pred = svc.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04        48
#            1       0.96      1.00      0.98      1151
#
#     accuracy                           0.96      1199
#    macro avg       0.98      0.51      0.51      1199
# weighted avg       0.96      0.96      0.94      1199
#
# [[   1   47]
#  [   0 1151]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-4208f75c55c2> in <module>
#       2 from sklearn.svm import SVC
#       3 ytr_pred = svc.predict(X_tr)
# ----> 4 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
# ----> 6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#       7
#       8 def generateClassificationReport_T(y_true,y_pred):
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.metrics import classification_report
from sklearn.svm import SVC
yt_pred = svc.predict(X_t)
generateClassificationReport_T(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.96      1.00      0.98       385
#
#     accuracy                           0.96       400
#    macro avg       0.48      0.50      0.49       400
# weighted avg       0.93      0.96      0.94       400
#
# [[  0  15]
#  [  0 385]]
# C:\Users\ME\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-6f61c8fd9e44> in <module>
#       2 from sklearn.svm import SVC
#       3 yt_pred = svc.predict(X_t)
# ----> 4 generateClassificationReport_T(y_t,yt_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_T(y_true, y_pred)
#      11     print(confusion_matrix(y_true,y_pred));
#      12     print('\n\nTest Accuracy is: ',
# ---> 13           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'accuracy_score' is not defined

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_tr,y_tr);

# %%
from sklearn.metrics import classification_report
ytr_pred = dtc.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        48
#            1       1.00      1.00      1.00      1151
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199
#
# [[  48    0]
#  [   0 1151]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-badccc30d908> in <module>
#       1 from sklearn.metrics import classification_report
#       2 ytr_pred = dtc.predict(X_tr)
# ----> 3 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
# ----> 6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#       7
#       8 def generateClassificationReport_T(y_true,y_pred):
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.metrics import classification_report
yt_pred = dtc.predict(X_t)
generateClassificationReport_T(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.15      0.20      0.17        15
#            1       0.97      0.96      0.96       385
#
#     accuracy                           0.93       400
#    macro avg       0.56      0.58      0.57       400
# weighted avg       0.94      0.93      0.93       400
#
# [[  3  12]
#  [ 17 368]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-9d92c4bcdb08> in <module>
#       1 from sklearn.metrics import classification_report
#       2 yt_pred = dtc.predict(X_t)
# ----> 3 generateClassificationReport_T(y_t,yt_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_T(y_true, y_pred)
#      11     print(confusion_matrix(y_true,y_pred));
#      12     print('\n\nTest Accuracy is: ',
# ---> 13           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'accuracy_score' is not defined

# %%
 import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
sgd = SGDClassifier()
sgd.fit(X_tr, y_tr);

# %%
from sklearn.metrics import classification_report
ytr_pred = sgd.predict(X_tr)
generateClassificationReport_Tr(y_tr,ytr_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        48
#            1       0.96      1.00      0.98      1151
#
#     accuracy                           0.96      1199
#    macro avg       0.48      0.50      0.49      1199
# weighted avg       0.92      0.96      0.94      1199
#
# [[   0   48]
#  [   0 1151]]
# C:\Users\ME\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-3f6734828774> in <module>
#       1 from sklearn.metrics import classification_report
#       2 ytr_pred = sgd.predict(X_tr)
# ----> 3 generateClassificationReport_Tr(y_tr,ytr_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_Tr(y_true, y_pred)
#       4     print(confusion_matrix(y_true,y_pred));
#       5     print('\n\nTrain Accuracy is: ',
# ----> 6           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#       7
#       8 def generateClassificationReport_T(y_true,y_pred):
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.metrics import classification_report
yt_pred = sgd.predict(X_t)
generateClassificationReport_T(y_t,yt_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        15
#            1       0.96      1.00      0.98       385
#
#     accuracy                           0.96       400
#    macro avg       0.48      0.50      0.49       400
# weighted avg       0.93      0.96      0.94       400
#
# [[  0  15]
#  [  0 385]]
# C:\Users\ME\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-7c6b5c41f144> in <module>
#       1 from sklearn.metrics import classification_report
#       2 yt_pred = sgd.predict(X_t)
# ----> 3 generateClassificationReport_T(y_t,yt_pred)
#
# <ipython-input-121-cc68654b8d0f> in generateClassificationReport_T(y_true, y_pred)
#      11     print(confusion_matrix(y_true,y_pred));
#      12     print('\n\nTest Accuracy is: ',
# ---> 13           round(100*accuracy_score(y_true,y_pred),3),'%\n');
#
# NameError: name 'accuracy_score' is not defined

# %%
#The Random Forest Classifier yielded an accuracy of 100%
